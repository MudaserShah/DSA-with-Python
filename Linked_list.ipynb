# %% [markdown]
# **Data Structures with Python**

# %%
class Node:
  def __init__(self, value):
    self.data = value
    self.next = None

class LinkdList:
  def __init__(self):
    self.head = None
    self.n = 0

  def __len__(self):
    return self.n

  def insert_head(self, value):
    new_node = Node(value)
    new_node.next = self.head
    self.head = new_node
    self.n = self.n + 1

  def __str__(self):
    temp = self.head
    result = ''
    while temp !=None:
      result = result + str(temp.data) + '->'
      temp = temp.next
    return result

  def append(self, value):
    new_node = Node(value)
    if self.head is None:
        self.head = new_node
        self.n += 1
        return  # stop here if the list was empty

    temp = self.head
    while temp.next is not None:
        temp = temp.next
    temp.next = new_node
    self.n += 1

  def insert_after(self, after, value):
    new_node = Node(value)
    curr = self.head
    while curr != None:
      if curr.data == after:
        break
      curr = curr.next
      #case 1 break -> item apko mil gya -> not
      #case 2 loop pura chala -> item nahi mila -> curr ->
    if curr != None:
      new_node.next = curr.next
      curr.next = new_node
      self.n = self.n + 1
    else:
      return 'Item not found'
  def clear(self):
    self.head = None
    self.n = 0

  def delete_head(self):
    if self.head != None:
       self.head = self.head.next
       self.n = self.n - 1
    else:
      return 'Empty List'
  def delete_tail(self):
    if self.head is None:  # empty list
        return 'Empty List'

    if self.head.next is None:  # only one element
        return self.delete_head()

    curr = self.head
    while curr.next.next is not None:
        curr = curr.next
    curr.next = None
    self.n -= 1
  def remove(self,value):

    if self.head == None:
      return 'Empty LL'

    if self.head.data == value:
      # you want to remove the head node
      return self.delete_head()

    curr = self.head

    while curr.next != None:
      if curr.next.data == value:
        break
      curr = curr.next

    # 2 cases item mil gaya
    # item nai mila
    if curr.next == None:
      # item nai mila
      return 'Not Found'
    else:
      curr.next = curr.next.next
      self.n = self.n - 1
  def search(self,item):

    curr = self.head
    pos = 0

    while curr != None:
      if curr.data == item:
        return pos
      curr = curr.next
      pos = pos + 1

    return 'Not Found'

  def __getitem__(self,index):

    curr = self.head
    pos = 0

    while curr != None:
      if pos == index:
        return curr.data
      curr = curr.next
      pos = pos + 1

    return 'IndexError'

  def __delitem__(self, index):
    if self.head == None:
      return 'Empty LL'

    if index == 0:
      return self.delete_head()

    curr = self.head
    pos = 0
    prev = None
    while curr != None:
      if pos == index:
        prev.next = curr.next
        self.n = self.n - 1
        return curr.data
      prev = curr
      curr = curr.next
      pos = pos + 1
    return 'IndexError'

# %%
L=LinkdList()
L.insert_head(1)

# %% [markdown]
# **Linked List**

# %%
class Node:
    def __init__(self, data=None):
        self.val = data
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None

# %% [markdown]
# **Push Operation**
#
# It have two use cases.:
# 1. When there are no nodes.
# 2. When there is already one or more node.

# %%
def push(self, val):
    new_node = Node(val)
    
    #no node cuurently
    if self.head is None:
        self.head = new_node
        return

    #otherwise reach the end and then insert
    last = self.head
    while last.next is not None:
        last = last.next
    last = new_node

# %% [markdown]
# **Pop Operation**
#
# Pop also has two cases:
# 1. When there is only one node.
# 2. Wheh there are multiple nodes.

# %%
def pop(self):
    if self.head is None:
        raise Exception("Cannot pop. No value.")
    
    # case 1 where there is only one node
    if self.head.next is None:
        val = self.head.val
        self.head = None #automatiz garbage collection
        return val
    # case 2 where there is 2 or more nodes 
    # reach the previous to last node
    temp = self.head
    while temp.next is not None:
        prev = temp

    val = temp.val
    prev.next = None
    return val

# %% [markdown]
# **Insertion Operation**
#
# Again Two cases:
# 1. Insertionat index 0: new head, old head becomes next of his nre head
# 2. Insertion at any index: in this case, move prev and temp forward index times. Then, insert new node b/w prev and temp.

# %%
def inert(self, index, val):
    new_node =Node(val)

    #Insertion at index 0 is different
    new_node.next = self.head
    self.head = new_node

    # for other indices
    temp = self.head

    counter = 0
    while temp is not None and counter < index:
        prev = temp
        temp = temp.next
        counter +=1
        #print(counter)
    
    #print("will inster after: ", prev.val)
    prev.next = new_node
    new_node.next = temp

# %% [markdown]
# **Remove Operation**
#
# This is also the same:
# 1.if first node is present and same as val, remove it.
# 2. otherwise, more prev and temp until temp points to the value. Set next of pre to next of temp. (Temp is lost)

# %%
def remove(self, val):
    temp = self.head

    #check first node
    if temp is not None:
        if temp.val ==val:
            self.head = temp.next
            return
    #let's move to next nodes
    # temp holds the value of the node that will be deleted
    while temp is not None:
        if temp.val == val:
            break

        prev = temp
        temp = temp.next
    if temp is None: #not found
        return
    prev.next = temp.next

# %% [markdown]
# **String Operation**

# %%
def __str__(self):
    temp = self.head
    result = ''
    while temp !=None:
      result = result + str(temp.data) + '->'
      temp = temp.next
    return result
